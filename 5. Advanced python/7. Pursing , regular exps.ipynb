# %% [markdown]
# Pursing -  security

# %%
# java script object notation

import json




# dumps() --- python(any dtype) to string 
# load()  -- convertion to original

# JSON parssing 
# Pickle Parsing

# %%
x=[30,50,180]

# %% [markdown]
# Regualr

# %%
# Date  :
    
    
# [0-9]{2}\/[0-9]{2}\/[0-9]{4}

# Time

# [0-9]{2}\:[0-9]\:{2}[0-9{2}]


# [Aa0-Zz0]+\@[a-z]{*}\.[a-z]{*}\.[a-z]{}


# Email :
#     generic expression:
        
#         \w+ \.? \_* \@ [a-z]+\. [a-z]{2,3} \.? [a-z]{2}
