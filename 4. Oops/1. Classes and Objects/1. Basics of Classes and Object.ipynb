# %% [markdown]
# Type of CLASS and Objects

# %%
# a,b,c='r'

a,b,c=1,2,3

class new:
    pass
obj=new()

print(type(obj))
print(type(new))
# Out:
# <class '__main__.new'>
# <class 'type'>

# %% [markdown]
# Classes and Object

# %%
class android_mobile:
    operating_system = 'android'
    OSBuild = 'Google'
    latest_version = 'Anroid_14'
    network = '4G / 5G'

noth=android_mobile()
moto=android_mobile()

noth.name = 'Nothing'
noth.color = 'White'
noth.storage = 120
noth.Processor = 'mediatek'
noth.display = 'Amoled'

moto.name = 'Motorola'
moto.color = 'Blue'
moto.storage = 120
moto.Processor = 'Snapdragon'
moto.display = 'IPSled'

print(android_mobile.operating_system, android_mobile.OSBuild , android_mobile.latest_version , android_mobile.network)

print(noth.name, noth.color, noth.storage, noth.Processor , noth.Processor, noth.display)

print(moto.name, moto.color, moto.storage, moto.Processor, moto.Processor, moto.display)
# Out:
# android Google Anroid_14 4G / 5G
# Nothing White 120 mediatek mediatek Amoled
# Motorola Blue 120 Snapdragon Snapdragon IPSled

# %% [markdown]
# -------Initialization Method------------ * __ init __ *

# %%
class ipl:
    no_team = 10
    overs = 20
    sponsor = 'TATA'
    
    def __init__(self,captain,cups_won,Stadium):
        self.captian=captain
        self.cups_won=cups_won
        self.stadium=Stadium

    def display(self):
        print("Team Name: RCB" ,self.captian,self.cups_won,self.stadium)
            
RCB=ipl('King' , 0,'Chinnaswamy')
RCB.display()
# Out:
# Team Name: RCB King 0 Chinnaswamy

# %% [markdown]
# Programs of REAL _ WORLD

# %%
class chat :
    
    contacts= {'dayan' : [],'ameen' : [] , 'salman' : [] , 'azeem' : [] , 'arbaz' : []}
    
    def send_msg(self):
        name = input("Enter the contact name")
        if name in chat.contacts :
            msg=input("enter the msg :")
            chat.contacts[name].append(msg)
        else :

            print('The contact asked is not present in the list Would you like to add him ? ')
            
class Insta(chat):
    pass
class facebook(chat):
    pass
class whatsapp(chat):
    pass

adarsh=Insta()
adarsh.send_msg()

# %% [markdown]
# Mmodification of above code to add a def function to add new contact to the dictionary

# %%
class Chat:
    contacts = {'dayan': [], 'ameen': [], 'salman': [], 'azeem': [], 'arbaz': []}
    
    def send_msg(self):
        name = input("Enter the contact name: ")
        if name in Chat.contacts:
            msg = input("Enter the message: ")
            Chat.contacts[name].append(msg)
        else:
            adddic = input("The contact asked is not present in the list. Would you like to add him? Y/n: ")
            if adddic.lower() == 'y':
                self.add_in_contact(name)

    @staticmethod
    def add_in_contact(name):
        Chat.contacts[name] = []
        
    @staticmethod
    def 

class Insta(Chat):
    pass

class Facebook(Chat):
    pass

class WhatsApp(Chat):
    pass

adarsh = Insta()
adarsh.send_msg()

print(Chat.contacts)
# Out:
# {'dayan': [], 'ameen': [], 'salman': [], 'azeem': [], 'arbaz': [], 'jinselin': []}

# %% [markdown]
# encapsulation----Private ---- Declaration , Accessing using traditional and syntax method

# %%
class Company:
    cname = "Accenture" 
    location = 'Bengaluru'
    __profit = '500cr'
    
    def __init__(self, ename, eid, sal, age):
        self.ename = ename
        self.eid = eid
        self.sal = sal
        self.__age = age

    def dis_age(self):
        return self.__age

 # other way to access the private access specifer 
    

vi = Company('Vijay', 'V123', 15000, 30)



print(vi.dis_age())                             # Correct way to access the private attribute
print(vi.ename)                                 # Correct way to access the public attribute



print(vi._Company__age)                         #traditional access syntax:   

# print(vi.__age)                               # This will cause an error because __age is a private attribute
# Out:
# 30
# Vijay
# 30
