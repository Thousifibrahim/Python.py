# %%
                   #  ELSE --- 02-09---2024

# %%
#WAP to check wheather the entire value is mutable or not
a = eval(input("Enter the value "))
if type(a) in [list,set,dict]:
    print("It is mutable")
else:
    print("It is immutable")
# Out:
# Enter :  5
# value is immutable

# %%
#WAP to check wheather the entire value is mutable or not

a = eval(input("Enter the value "))
if type(a) in [list,set,dict]:
    print("It is mutable")
else:
    print("It is immutable")
# Out:
# Enter :  5
# value is immutable

# %%
#WAP to check whether the entire character is vowel or not

a=input("Enter the string  ")
if a in ['a','e','i','o','u','A','E','I','O','U']:
    print("Vowel is present")
else:
    print("Vowel is not present")

# %%
# -------------------------Alternative-------------------
#WAP to check whether the entire character is vowel or not
a=input("Enter the string  ")
if a in ['aeiouAEIOU']:
    print("Vowel is present")
else:
    print("Vowel is not present")

# %%
# wat to check weather the number is even or odd
a =int( input("Enter : "))
if a%2 == 0:
    print("the number is even",a)
else :
    print("The number is odd",a)
# Out:
# Enter :  2
# the number is even

# %%
#1. wap to check wheather the entered character is upper case or not
a = input("Enter the character")
if 'A' >a[0] and a[0] >'Z':
    print("charcter is upper case",a)
else :
    print("charcter is lower case")
# Out:
# Enter the character a
# charcter is lower case

# %%
#2. wap print the first  character of the string only if the last character of it is uppercase
a = input("Enter the character")
if 'A'<a[-1]<'Z':
    print("Itsupper case ",a[0])
else : 
    print("the last Character is not in upper case")
# Out:
# Enter the character bckbskvbs
# the last Character is not in upper case

# %%
#3. WAP to print the reversed string if the length is odd and print the characters at even index if the length is even
a = input("Enter the character")
if len(a)%2 == 0:
    print(a[::2])
else : 
    print(a[::-1])
# Out:
# Enter the character kcbsc
# csbck

# %%
# 4.WAP to check whether the last value of a list is single Value or collection
l = eval(input("Enter the character:"))
if type(l[-1]) in [list,tuple,set,dict,str]  :
    print(" is a collection")
else : 
    print("is not a collection")
# Out:
# Enter the character: [1,2,3,4,{'set'}]
#  is a collection

# %%
# to print the middle value and if there is a middle charcter present in the strings
#WAP to check whether the string is having middle character or not and print if it is present print (middle character)

a = input("Enter the string: ")
if len(a) % 2 == 1:
    mid_index = len(a) // 2
    print("Middle character:", a[mid_index])
else:
    print("The string middle character is not determined.")
