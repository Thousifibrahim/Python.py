# %% [markdown]
# # --------------BREAK------------------

# %%
for i in range(0,5):
    if i==4:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(1,5):
    if i ==3 and  i ==4 :
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# WAP consider username and passwords  of a , user make the user Login only if he enters valid username valid username and password 
# NOTE  : USER Should enter the password only if the username is correct (valid)

un = 'jin'
ps = '123'
unn =input("ENter a UNAME :")  

while True:
    if un == unn:
        pswd=input("ENter a PWD :")
        if ps == pswd :
            print("Login Sucess")
            break
            
        else:
            print("password Wrong")
    else:
        print("Username wrong")
print("PYTHON")
# Out:
# password Wrong
# password Wrong
# Login Sucess
# PYTHON

# %%
# WAP to print the index if the first list present in a tuple collection ----------------------------LIST INDEX and stop--------------

tf= (1,2,3,4,5,[44,444],6)

for i in range(0,len(tf)):
    if type(tf[i]) == list:
        break
print(i)
# Out:
# 5

# %%
#IMPORTANT
# WAP to check weather the entered number is PRIME number or NOT .

a=int(input("Enter"))

if a>1:
    for i in range(2,a):                          # 3----for i in range(2,(x//2)+1)
        if a%i==0:
            print("Not a prime")
            break
    else:
        print("PRIME")
else:
    print("Entered number is less than 1")
# Out:
# Not a prime

# %%
x = 4
out = []
for i in range(1,x+1):
    if x%i==0:
        out+=[i]

if len(out)==2:
    print('PRIME')
else:
    print("NOT A PRIME")
# Out:
# NO A PRIME

# %%
# WAP to check weather the string is having only upper case characters or not ---------------------TRADITIONAL

r = 'BEN'
ou = ''

for i in r:
    if 'A'<= i <='Z' :
        ou +=i
        
if len(ou)==len(r):
     print("All are Upper case")
else:
    print("it is not in upper case")
# Out:
# it is not in upper case

# %%
# WAP to check weather the string is having only upper case characters or not---------------------------------------USING BREAK MORE EFFICIENT

r = 'ADITHYA'
for i in r:
    if not ('A'<= i <='Z') :
        print("Not in Upper case")
        break   
else:
    print("ALL are Upper case ")
# Out:
# ALL are Upper case

# %%
# WAP to check weather list is HOMOGENOUS or HETROGENOUS--------------------------------WITHOUT RANGE

list = [1,2,3,4,5,6,7]
 
for i in list :
    if type(i) != type(list[x]):
        print("Het")
        break
else:
    print("Hom")
# Out:
# Hom

# %%
#------------------------WITH RANGE ------------------------#

# %%
# WAP to find the smallest factor of a integer number other than 1 

num = int(input("Enter a number: "))
for i in range(2, num):
    if num % i == 0:
        print("THe smallest factor",i)
        break
else:
    print(num)
# Out:
# THe smallest factor 2

# %% [markdown]
# # -------------continue------------------

# %%
#Continue statement 
for i in range(1,6):
    if i==2:
        continue
    else:
        print(i)
# Out:
# 1
# 3
# 4
# 5

# %%
for i in range(1,6):
    continue
    print(i)

# %%
for i in range(1,6):
    print(i)
    continue
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#WAP to extract even number which are present inside hetrogenous list collection
a=[1,2,3,4,6,7,8,"sdfghjkl"]
b=[]
for i in a:
    if type(i)==int:
        if i%2!=0:
            continue
        else:
            b+=[i]
print(b)
# Out:
# [2, 4, 6, 8]

# %%
#WAP to count the numbers of uppercase alphabets in a given string using continue
a="ASDFGHqwerty@$%^&045@#$%AERG"
count=0
for i in a:
    if not ('A'<=i<='Z' or 'a'<=i<='z' or '0'<=i<='9') or 'a'<=i<='z' or '0'<=i<='9':
        continue
    else:
        count+=1
print(count)
# Out:
# 10

# %%
#WAP to count the numbers of uppercase alphabets in a given string using continue
a="ASDFGHqwerty@$%^&045@#$%AERG"
count=0
for i in a:
    if not ('A'<=i<='Z'):
        continue
    else:
        count+=1
print(count)
# Out:
# 10

# %%
#WAP to extract digits from the string collection
a="ASDFGHqwerty@$%^&045@#$%AERG"
count=' '
for i in a:
    if not ('0'<=i<='9'):
        continue
    else:
        count+=i
print(count)
# Out:
#  045

# %%
#WAP to get the following output
si='1110010'
sj='1101010'
out=0
for i in range(len(si)):
    if si[i]!=sj[i]:
        out+=1
print(out)
# Out:
# 2

# %% [markdown]
# GENERAL PROGRAMS

# %%
st='Abc8#*$zbE'
B,c,no,sp=0,0,0,0
upr,lwr,num,spc='','','',''
for i in st:
    if 'A'<=i<='Z':
        B+=1
        upr+=i
    elif 'a'<=i<='z':
        c+=1
        lwr+=i
    elif '0'<=i<='9':
        no+=1
        num+=i
    else:
        sp+=1
        spc+=i
d={upr:B, lwr:c, num:no,spc:sp}
print(d)
# Out:
# {'AE': 2, 'bczb': 4, '8': 1, '#*$': 3}

# %%
st='Abc8#*$zbE'
upr,lwr,num,spc='','','',''
for i in st:
    if 'A'<=i<='Z':
        upr+=i
    elif 'a'<=i<='z':
        lwr+=i
    elif '0'<=i<='9':
        num+=i
    else:
        spc+=i
d={upr:len(upr), lwr:len(lwr), num:len(num),spc:len(spc)}
print(d)
# Out:
# {'AE': 2, 'bczb': 4, '8': 1, '#*$': 3}

# %%
while True:
    a=input("enter")
    if a=="":
        print("please enter something")
        continue
    elif a=="STOP":
        break
    print(a)

# %%
a=["jensilin","Aditya","Shakthi"]
b={}
for i in a:
    count=0
    for j in i:
        if j in 'AEIOUaeiou':
            count+=1
        b[i]=count
print(b)
# Out:
# {'jensilin': 3, 'Aditya': 3, 'Shakthi': 2}

# %%
#write a program to extract palindrome words form a given sentence
a="MOM DAD MALAYALAM TAMIL"
b=a.split()
palin=""
for i in b:
    if i[::-1]==i:
        palin+=i+" "
print(palin)

# %%
# ['hai',3+4j,15,'good',35]
# op=[6,8]
a=['hai',3+4j,15,'good',35]
z=[]
for i in a:
    if type(i)==int:
        b=str(i)
        c=b[0]
        d=b[-1]
        e=int(c)+int(d)
        z+=[e]
print(z)

# %%
#Nested for loop
for i in range(3):
    for j in range(6):
        print(i,j)

# %%
for i in range(1,6,3):
    for j in range(11,25,6):
        for k in range(30,50,10):
            print(i,j,k)

# %%
#a="kannadave sathya kanndavuu nithya"
a="kannadave sathya kanndavuu nithya"
c=a.split()
b={}
for i in c:
    count=0
    for j in i:
        if j in 'aeiouAEIOU':
            count+=1
    b[i]=count
print(b)

# %%
#int print 1
#str and palindrome print length
#str and non palindrome reversed string
a=[120,"sdfgthy","sdefrgty",541,"mom"]
out=[]
for i in a:
    c,d='',0
    if type(i)==int:
        out+=[1]
    if type(i)==str:
        for j in i:
            c=j+c
            d+=1
        if c==i:
            out+=[d]
        else:
            out+=[c]
print(out)

# %%
#WAP
#a="kannadave sathya kanndavuu nithya"
a="kannadave sathya kanndavuu nithya"
c=a.split()
b={}
for i in c:
    count=0
    for j in i:
        count+=1
    b[i]=count
print(b)

# %%
a=[123,'madve ota',445,92.7,3+2j,312]
b=[]
for i in a:
    rev=0
    if type(i)==int:
        while i!=0:
            ld=i%10
            rev=rev*10+ld
            i=i//10
        b+=[rev]
    else:
        b+=[i]
print(b)

# %%
#
for i in "Satyam":
    for j in i:
        print(j)
# Out:
# S
# a
# t
# y
# a
# m

# %%
#WAP to get the following output
a="vimal pan masala"
z={}
b=a.split()
print(b)
#length of odd consonanats
#length is even vowels
for i in b:
    eve=''
    evj=''
    count=0
    for j in i:
        evj+=j
        count+=1
    if count%2==0:
        if evj in 'aeiouAEIOU':
            eve+=evj
    else:
        if not eve in 'aeiouAEIOU':
            eve+=''
    z[i]=[eve,count]
print(z)
# Out:
# ['vimal', 'pan', 'masala']
# {'vimal': ['', 5], 'pan': ['', 3], 'masala': ['', 6]}

# %%
#WAP to get the following output
a="vimal pan masala"
out={}
x=a.split()

#length of odd consonanats
#length is even vowels
for i in x:
    if len(i)%2==0:
        con=''
        for j in i:
            if 'A'<=j<='Z' or 'a'<=j<='z':
                if j not in "aeiouAEIOU":
                    con+=j
        out[i]=[con,len(con)]
    else:
        vow=''
        for j in i:
            if j in 'aeiouAEIOU':
                vow+=j
        out[i]=[vow,len(vow)]
print(out)
# Out:
# {'vimal': ['ia', 2], 'pan': ['a', 1], 'masala': ['msl', 3]}

# %%
#WAP to get the following output
a="vimal pan masala"
out={}
x=a.split()

#length of odd consonanats
#length is even vowels
for i in x:
    vov=''
    con=''
    eve=''
    count=0
    for j in i:
        count+=1
        print(count)
# Out:
# 1
# 2
# 3
# 4
# 5
# 1
# 2
# 3
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#WAP to write number of characters 
#output in dictionary
a='abbcderttijijobbrff'
b=''
# count=0
for i in a:
    if i not in b:
        count=0
        for j in a:
            if i == j:
                count+=1
        b+=i+str(count)+" "
print(b)
# Out:
# a1 b4 c1 d1 e1 r2 t2 i2 j2 o1 f2

# %%
a='aaabbcaaccbbb'
count=1
b=''
for i in range(0,len(a)-1):
    if a[i] == a[i+1]:
        count+=1
    else:
        b+=a[i]+str(count)+" "
        count=1
b+=a[-1]+str(count)+" "
print(b)
# Out:
# a3 b2 c1 a2 c2 b3
