# %% [markdown]
# BASICS

# %%
#def function
#functions without argument and without return values
def add():
    x=int(input("Enter"))
    y=int(input("enter"))
    print(x+y)
add()
# Out:
# 7

# %%
#WAP to count the number of integers present in a list collection
def count():
    a=[1,2,3,4,5,"wdertyu7u89"]
    cpunt=0
    for i in a:
        if type(i)==int:
            cpunt+=1
    print(cpunt)
count()
# Out:
# 5

# %%
#WAP to print all the upper case characters in a string collection   using DEF 

def upper(str):
    for i in str:
        if i.isupper():
            print(i)
upper('ThousifS')
# Out:
# T
# S

# %%
# same in whiile loop

def upper(str):
    i = 0
    while i < len(str):
        if 'A'<=str[i]<='Z':
            print(str[i] , end=' ')
        i+=1
upper('SHahiD')
# Out:
# S H D

# %%
# ----------------------------------- Programs

# %%
# WAP to remove Duplicates from the list collecetion without CONVERTING to set

def remove_Duplicate(list):
    out = []
    for i in list :
        if i not in out:
                out+=[i]
print(out)
remove_Duplicate(eval(input("Enter:")))
# Out:
# []

# %%
# WAP to extract common elements in Two list Collection 
                                #    ---------WRONG-----------
                                
def common(li1,li2):
    out = []
    for i in li1:
        if i in li2:
            if i not in out:
                out+=[i]
    print(out)
    
# INPUT :  common([8,6,6,0,6,6,6,8,3,3],[9,1,1,0,8,4,8,7,1,7])


# def cm(l1,l2):
#     out = []
#     for i in l1:
#         if i in l2:
#             for j in l2:
#                 if i==j:
#                     out+=[i]
#     print(out)
# cm(eval(input()),eval(input()))

# # [9,1,1,0,8,4,8,7,1,7]
# # [8,6,6,0,6,6,6,8,3,3]
# Out:
# [9, 5, 5, 6, 6]

# %%
# # WAP to get following output st1 = '110011' st2 = '101101   o/p = 2 

# same elements at same index in both the String

                
def same(st1, st2):
    if len(st1) == len(st2):
        out = 0
        for i in range(len(st1)):
            if st1[i] == st2[i]:
                out += 1
        print(out)
    else:
        print("Strings are of different lengths")
same('110011','101101')
    
# st1 = '110011'
# st2 = '101101'

# %% [markdown]
# RETURN

# %%
def addition(a,b):
    c= a+b
    print(c)
addition(4,7)
# Out:
# 11

# %%
def addition(a,b):
    return a+b,a*b,a-b
add=addition(4,6)
print(add)
# Out:
# (10, 24, -2)

# %%
def ret():
    return 1+5 ,10-20 ,10*50
ret()
# Out:
# (6, -10, 500)

# %%
def prod(a,b):
    return a*b , a^b
prod(44,66)
# Out:
# (2904, 110)

# %%
#WAP to which counts all the voewels present in string collection and
# display the out in the form of dictionary where
#in keys must be reversed string and value must be the count 

a = 'bengaluru is the  capital of karnataka'

# %%
def add(a,b,c):
    return a+b+c
print(add(2,4,5))
# Out:
# 11

# %%
def add(a,b,c):
    return a+b+c
print(add(2,4,5))


def sum_of_integers_in_list(a):
    total_sum = sum([num for num in a if isinstance(num, int)])
    return total_sum
a = eval(input("Enter the list: "))
print("Sum of all integers in the list:", sum_of_integers_in_list(a))
# Out:
# 11

# %% [markdown]
# # TYPES OF FUNCTION SYNTAX

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# WAP to find Sum of all the integers preesent in list Collection
 
 
 
lst=eval(input("Enter the list :"))
sum=0
for i in lst:
    if type(i) == int :
        sum +=i
print(sum)
# Out:
# 74

# %% [markdown]
# USING DIFF FUNCTION

# %%
def sum():

    lst=eval(input("Enter the list :"))
    sum = 0
    for  i in range(len(lst)):
        if type(i) == int :
            sum +=i
    print(sum)

# %%
# WAP To get the Follwing Output 'nale  class ide'
# OUTPUT :{ 'nale' ['ne' , 'elan'] , 'class' : ['cas','a'] , 'idee' :['iee','ieee']}


st = 'nale  class ide'
sr = st.split()
dct = {}
print(sr)
for i in sr:
    if len(i)%2==0:
        a1 = i[0] + i [-1]
        a2  = i[::-1]
        dct[i] = [a1,a2]
    else:
        even = i[::2] 
        vow = ''
        for j in i:
            if j in  'aeiuoAEIOU':
                vow+=j
            dct[i]=[even,vow]
print(dct)
# Out:
# ['nale', 'class', 'ide']
# {'nale': ['ne', 'elan'], 'class': ['cas', 'a'], 'ide': ['ie', 'ie']}

# %%
def dct(st):
    sr = st.split()
    dct = {}
    print(sr)
    for i in sr:
        if len(i)%2==0:
            a1 = i[0] + i [-1]
            a2  = i[::-1]
            dct[i] = [a1,a2]
        else:
            even = i[::2] 
            vow = ''
            for j in i:
                if j in  'aeiuoAEIOU':
                    vow+=j
                dct[i]=[even,vow]
    return dct
print(dct('nale  class ide'))
# Out:
# ['nale', 'class', 'ide']
# {'nale': ['ne', 'elan'], 'class': ['cas', 'a'], 'ide': ['ie', 'ie']}

# %%
# WAP tp extract all the prime numbers present in list Collection 

lst = [3,'brea', 'Stop', 5,21, 20]
integres  = []
for i in lst:
    if type(i) == int:
        integres = + integres[i]
        
        for j in integres:
            if j > 1 :
                
                for k in range(2, int(j**0.5) + 1):
                        if j % k == 0:
                            is_prime = False 
                            break
                        if is_prime:
                            prime_numbers.append(j)

print(prime_numbers)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 7
#       5 for i in lst:
#       6     if type(i) == int:
# ----> 7         integres = + integres[i]
#       9         for j in integres:
#      10             if j > 1 :
#
# IndexError: list index out of range

# %% [markdown]
# Saturday incomplete

# %%
def add(*a):
    total_sum = 0
    for i in a:
        if isinstance(i, int) and len(a) <= 5:
            total_sum += i
    return total_sum

# Example usage
result = add(1, 2, 3, 4, 5, 6, 7, 5, 6)
print(result)
# Out:
# 0

# %%
def add(a,b,c=0,d=0):
    print(a+b+c+d)
add(2,3)
# Out:
# 5

# %%
"""# WAP to find product of min two integers max four integeres
--------------------------------------------
# For Product value 1 """

def prod(a,b,c=1, d=1):
    print(a*b*c*d)
prod(int(input("ENter:")),int(input("ENter:")))
# Out:
# 2420

# %% [markdown]
# FLow of execution

# %%
s = 8
def py():
    s=5
    print(s)
    print('sunday')
print(s,s)
py()
print(s+s)
# Out:
# 8 8
# 5
# sunday
# 16

# %% [markdown]
# Global

# %%
s = 8
def glob():
    pass
